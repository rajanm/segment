# %% [markdown]
# <a href="https://colab.research.google.com/github/rajanm/segment/blob/main/Segment_of_One.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data_url = 'https://raw.githubusercontent.com/rajanm/segment/main/data/Hackathon_Working_Data.csv'
nielsen_df = pd.read_csv(data_url)

# %%
nielsen_df.head(5)
# Out:
#   MONTH STORECODE  DAY BILL_ID  BILL_AMT  QTY  VALUE  PRICE  \
# 0    M1        N1    4    T375     225.0  1.0  225.0  225.0
# 1    M1        N1    4    T379      95.0  1.0   95.0   95.0
# 2    M1        N1    4    T381      10.0  1.0   10.0   10.0
# 3    M1        N1    4    T382     108.0  1.0  108.0  108.0
# 4    M1        N1    4    T384      19.0  1.0   19.0   19.0
#
#                        GRP                     SGRP                    SSGRP  \
# 0     BUTTER MARGR  (4/94)                   BUTTER                   SALTED
# 1  CONFECTIONERY - ECLAIRS  CONFECTIONERY - ECLAIRS  CONFECTIONERY - ECLAIRS
# 2                CHOCOLATE         CHOCOLATE PANNED         CHOCOLATE PANNED
# 3             PACKAGED TEA               MAIN PACKS               MAIN PACKS
# 4         ALL IODISED SALT            POWDERED SALT            POWDERED SALT
#
#                       CMP           MBRD                 BRD
# 0               G C M M F           AMUL                AMUL
# ...

# %% [markdown]
# Let's do some exploratory data analysis (EDA) on the nielsen dataset. Reference on EDA [here](https://www.analyticsvidhya.com/blog/2021/04/top-python-libraries-to-automate-exploratory-data-analysis-in-2021/).

# %%
# !pip install dtale
# !pip install fastapi
# !pip install python-multipart
# !pip install uvicorn

# %%
import dtale
d = dtale.show(nielsen_df)
d.open_browser()

# %%
# !pip install sweetviz

# %%
import sweetviz
nielsen_report  = sweetviz.analyze([nielsen_df,'STORECODE,DAY'], target_feat='BILL_AMT')
nielsen_report.show_html('nielsen_eda_report.html')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report nielsen_eda_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
nielsen_txn_df = nielsen_df.groupby(['STORECODE','MONTH','BILL_ID','GRP','SSGRP','CMP','BRD','QTY','PRICE'])['BILL_AMT'].sum()

# %%
nielsen_txn_df.head(50)
# Out:
# STORECODE  MONTH  BILL_ID  GRP                           SSGRP                        CMP                             BRD                             QTY   PRICE
# N1         M1     T1000    SPICES (03/04)                ASOFOETIDA/HING-PURE MASALA  S NARENDRA KUMAR                EVEREST                         1.0   70.00      98.00
#                                                          CHILLY POWDER-PURE SPICES    S NARENDRA KUMAR                EVEREST                         1.0   28.00      98.00
#                   T1001    BISCUITS - CORE & NON CORE    SALT CRACKER                 PARLE PRODS                     MONACO                          1.0   5.00       53.46
#                            BLUES                         LIQUID BLUES                 JYOTHY LABORATORIES             UJALA SUPREME                   1.0   22.00      53.46
# ...

# %%
nielsen_txn_report  = sweetviz.analyze([nielsen_df,'STORECODE,BILL_ID,GRP,SSGRP,CMP,BRD,QTY,PRICE'], target_feat='BILL_AMT')
nielsen_txn_report.show_html('nielsen_txn_eda_report.html')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report nielsen_txn_eda_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
nielsen_txn_m1_df = nielsen_df[(nielsen_df['MONTH'].str.contains('M1')) & (nielsen_df['DAY']==1) & (nielsen_df['BILL_AMT']>=850.0)]
nielsen_txn_m1_df.count()
# Out:
# MONTH        17
# STORECODE    17
# DAY          17
# BILL_ID      17
# BILL_AMT     17
# QTY          17
# VALUE        17
# PRICE        17
# GRP          17
# SGRP         17
# SSGRP        17
# CMP          17
# MBRD         17
# BRD          17
# dtype: int64
