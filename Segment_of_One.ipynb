# %% [markdown]
# <a href="https://colab.research.google.com/github/rajanm/segment/blob/main/Segment_of_One.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data_url = 'https://raw.githubusercontent.com/rajanm/segment/main/data/Hackathon_Working_Data.csv'
neilsen_df = pd.read_csv(data_url)

# %%
neilsen_df.head(5)
# Out:
#   MONTH STORECODE  DAY BILL_ID  BILL_AMT  QTY  VALUE  PRICE  \
# 0    M1        N1    4    T375     225.0  1.0  225.0  225.0
# 1    M1        N1    4    T379      95.0  1.0   95.0   95.0
# 2    M1        N1    4    T381      10.0  1.0   10.0   10.0
# 3    M1        N1    4    T382     108.0  1.0  108.0  108.0
# 4    M1        N1    4    T384      19.0  1.0   19.0   19.0
#
#                        GRP                     SGRP                    SSGRP  \
# 0     BUTTER MARGR  (4/94)                   BUTTER                   SALTED
# 1  CONFECTIONERY - ECLAIRS  CONFECTIONERY - ECLAIRS  CONFECTIONERY - ECLAIRS
# 2                CHOCOLATE         CHOCOLATE PANNED         CHOCOLATE PANNED
# 3             PACKAGED TEA               MAIN PACKS               MAIN PACKS
# 4         ALL IODISED SALT            POWDERED SALT            POWDERED SALT
#
#                       CMP           MBRD                 BRD
# 0               G C M M F           AMUL                AMUL
# ...

# %% [markdown]
# Let's do some exploratory data analysis (EDA) on the neilsen dataset. Reference on EDA [here](https://www.analyticsvidhya.com/blog/2021/04/top-python-libraries-to-automate-exploratory-data-analysis-in-2021/).

# %%
# !pip install dtale
# !pip install fastapi
# !pip install python-multipart
# !pip install uvicorn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 7.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# tensorflow-probability 0.22.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.8.0 which is incompatible.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 1.3 MB/s eta 0:00:00
# ...

# %%
import dtale
d = dtale.show(neilsen_df)
d.open_browser()

# %%
# !pip install pip install sweetviz
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 52.9 MB/s eta 0:00:00
# ...

# %%
import sweetviz
neilsen_report  = sweetviz.analyze([neilsen_df,'STORECODE,DAY'], target_feat='BILL_AMT')
neilsen_report.show_html('neilsen_eda_report.html')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report neilsen_eda_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
neilsen_txn_df = neilsen_df.groupby(['STORECODE','MONTH','BILL_ID','GRP','BRD','QTY','PRICE'])['BILL_AMT'].sum()

# %%
neilsen_txn_df.head(25)
# Out:
# STORECODE  MONTH  BILL_ID  GRP                           BRD                             QTY  PRICE
# N1         M1     T1000    SPICES (03/04)                EVEREST                         1.0  28.00     98.00
#                                                                                               70.00     98.00
#                   T1001    BISCUITS - CORE & NON CORE    MONACO                          1.0  5.00      53.46
#                            BLUES                         UJALA SUPREME                   1.0  22.00     53.46
#                            SPICES (03/04)                EVEREST                         1.0  26.46     53.46
#                   T1003    SALTY SNACKS (2/97)           KUR KURE HYDRABADI HUNGAMA      1.0  10.00     10.00
#                   T1004    BISCUITS - CORE & NON CORE    GONE MAD                        1.0  5.00       5.00
#                   T1005    CHOCOLATE                     DAIRY MILK                      1.0  20.00     22.00
# ...

# %%
neilsen_txn_report  = sweetviz.analyze([neilsen_df,'STORECODE,BILL_ID,GRP,BRD,QTY,PRICE'], target_feat='BILL_AMT')
neilsen_txn_report.show_html('neilsen_txn_eda_report.html')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report neilsen_txn_eda_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
